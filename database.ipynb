# %% [markdown]
# # Database creation and management routine testing
#
# This notebook mostly contains scrapwork for the `database.py` module file. The code below is intended for testing and experimentation. See the documentation in `database.py` for how to work with the database to add and retrieve data.

# %% [markdown]
# ## Universal imports

# %%
from imdb import IMDb as i  # IMDb API handling
import sqlalchemy as al     # SQL interface helper for IMDb db creation
import requests as r        # HTTP handling
import sqlite3 as s         # SQLite3 database
import pandas as pd         # Data handling
import numpy as np          # Math utilities
import json as j            # JSON handling
import bs4 as bs            # HTML handling
import os

# %% [markdown]
# ## Global variable declarations

# %%
SCRIPTS = './scripts/{}' # Scripts folder location for loading operations
IMDB = 'sqlite:////Users/matt.tranquada/Documents/ga-capstone/imdb/imdb.db' # Local database location (absolute)
DB = 'test.db' # Test database configuration - comment out when production-ready
#DB = 'films.db'

# %% [markdown]
# ## IMDbPy database setup

# %%
# Search testing
films = i('s3',IMDB)
results = films.search_movie('aliens')
for result in results:
    print(result.movieID, result)
# Out:
# 7285968 Aliens
# 6287306 Aliens
# 5277916 Aliens
# 3837024 Aliens
# 3380630 Aliens
# 3154258 Aliens
# 1419286 Aliens
# 1374820 Aliens
# 324979 Aliens
# 296497 Aliens
# 90605 Aliens
# 7355350 Alienus
# 324980 Aliens?
# 5584694 2 Aliens
# 2339343 Aliens!?
# 7992738 Aliens
# 7445256 Aliens
# 7400460 Aliens
# 7252392 Aliens
# 7248186 Aliens

# %%
results[10]
# Out:
# <Movie id:90605[s3] title:_Aliens (None)_>

# %%
titles = [x[:-5] for x in os.listdir('./scripts')]
titles
# Out:
# ['Invention of Lying, The',
#  'Machine Gun Preacher',
#  "Jennifer's Body",
#  'Cellular',
#  'Rambling Rose',
#  'Someone To Watch Over Me',
#  'Beasts of the Southern Wild',
#  'Family Man, The',
#  'Trainspotting',
#  'Antz',
#  'Aliens',
#  'Martha Marcy May Marlene',
#  'Birthday Girl',
#  'Sherlock Holmes',
#  'I, Robot',
#  'Fletch',
#  "Ocean's Twelve",
#  'Runaway Bride',
#  'Little Athens',
#  'Resident Evil',
#  "All the King's Men",
#  'Foxcatcher',
#  'Liar Liar',
#  'Despicable Me 2',
#  'South Park',
#  'Misery',
#  'Wild Wild West',
#  'White Ribbon, The',
#  'Scream 2',
#  'White Christmas',
#  'Big Eyes',
#  "King's Speech, The",
#  'Bodyguard',
#  'Les Miserables',
#  'How to Lose Friends & Alienate People',
#  'Ghostbusters',
#  'Chinatown',
#  'Beloved',
#  'Terminator',
#  'Basic Instinct',
#  'Jennifer Eight',
#  'Flash Gordon',
#  'Bad Dreams',
#  'Taking Lives',
#  'Gothika',
#  'Frances',
#  'Next Friday',
#  'Copycat',
#  'Pet Sematary II',
#  'Game, The',
#  'Shifty',
#  'Erik the Viking',
#  'Amelia',
#  'Die Hard 2',
#  'Lock, Stock and Two Smoking Barrels',
#  'Toy Story',
#  'Matchstick Men',
#  '10 Things I Hate About You',
#  'Broadcast News',
#  'Timber Falls',
#  'Escape From L.A.',
#  "Cirque du Freak: The Vampire's Assistant",
#  'All About Steve',
#  'Event Horizon',
#  'Bringing Out the Dead',
#  'American Hustle',
#  'Gamer',
#  'Drop Dead Gorgeous',
#  'As Good As It Gets',
#  'Day the Earth Stood Still, The',
#  'I Spit on Your Grave',
#  'Box, The',
#  'Flight',
#  'Elizabeth: The Golden Age',
#  'Insomnia',
#  'Apollo 13',
#  'Honeydripper',
#  "Hitchhiker's Guide to the Galaxy, The",
#  'Things My Father Never Taught Me, The',
#  'Barton Fink',
#  'Peggy Sue Got Married',
#  'Escape From New York',
#  'Robin Hood: Prince of Thieves',
#  'Crouching Tiger, Hidden Dragon',
#  'Harry Potter and the Deathly Hallows Part 1',
#  'Lion King, The',
#  'Human Nature',
#  'Mary Poppins',
#  'Life of David Gale, The',
#  'Point Break',
#  'Rocky',
#  'American Madness',
#  'Supergirl',
#  'Casablanca',
#  'Siege, The',
#  'Sessions, The',
#  'Babel',
#  'Ticker',
#  'Frankenstein',
#  'Shakespeare in Love',
#  'Real Genius',
#  'Agnes of God',
#  'Frequency',
#  'Wolf of Wall Street, The',
#  'Girl with the Dragon Tattoo, The',
#  'Apocalypse Now',
#  'Rush',
#  'Jade',
#  'Passion of Joan of Arc, The',
#  'Walk to Remember, A',
#  'High Fidelity',
#  'Margin Call',
#  'Drag Me to Hell',
#  'Last Station, The',
#  'Arctic Blue',
#  'Fruitvale Station',
#  'Kafka',
#  'Slither',
#  'Tristan and Isolde',
#  'Clash of the Titans',
#  'Miracle Worker, The',
#  'So I Married an Axe Murderer',
#  'TMNT',
#  'Pianist, The',
#  'Eastern Promises',
#  'Limey, The',
#  'World is not Enough, The',
#  'Nightmare on Elm Street, A',
#  'Serenity',
#  'Brazil',
#  'American Graffiti',
#  'Cube',
#  'Happy Birthday, Wanda June',
#  'Gremlins',
#  'Shrek the Third',
#  'Election',
#  'Thing, The',
#  'Jaws',
#  'Broken Arrow',
#  'Colombiana',
#  'Kate & Leopold',
#  'Labyrinth',
#  'Matrix Reloaded, The',
#  'Get on Up',
#  'Moonrise Kingdom',
#  'Feast',
#  'American Werewolf in London',
#  'Benny & Joon',
#  'Burlesque',
#  'Batman Returns',
#  'Alone in the Dark',
#  'Break',
#  'Harold and Kumar Go to White Castle',
#  'My Girl',
#  'Die Hard',
#  'Terminator Salvation',
#  'Crow Salvation, The',
#  'Rebel Without A Cause',
#  '.DS_',
#  'Sunset Blvd.',
#  'Labor of Love',
#  'Amour',
#  'Unforgiven',
#  'Charade',
#  'Friday the 13th Part VIII: Jason Takes Manhattan',
#  'Sneakers',
#  'Arsenic and Old Lace',
#  'Saving Mr. Banks',
#  'Who Framed Roger Rabbit?',
#  'Metro',
#  'Croupier',
#  'Bad Day at Black Rock',
#  'L.A. Confidential',
#  'Distinguished Gentleman, The',
#  'Shame',
#  'Punch-Drunk Love',
#  'Deception',
#  'Valkyrie',
#  'Ides of March, The',
#  'Crash',
#  'Diner',
#  'Inventing the Abbotts',
#  'Mr Blandings Builds His Dream House',
#  'Swingers',
#  'Usual Suspects, The',
#  'Strangers on a Train',
#  'Power of One, The',
#  'Getaway, The',
#  'Total Recall',
#  'Withnail and I',
#  'Avengers, The (2012)',
#  'Bling Ring, The',
#  'Mulan',
#  'Pacifier, The',
#  'King Kong',
#  'Lone Star',
#  'Looper',
#  'A Serious Man',
#  'Blade II',
#  'Jane Eyre',
#  'In the Bedroom',
#  'Hannibal',
#  'Hostage',
#  'Super 8',
#  'No Strings Attached',
#  'Disturbia',
#  'Burn After Reading',
#  "Mr. Holland's Opus",
#  'Wall Street: Money Never Sleeps',
#  'Cliffhanger',
#  'Obsessed',
#  'Eight Legged Freaks',
#  "Devil's Advocate",
#  'Max Payne',
#  'Elephant Man, The',
#  'Wall-E',
#  'Pariah',
#  'Bonfire of the Vanities',
#  'After.Life',
#  'Incredibles, The',
#  'Insider, The',
#  'Man Trouble',
#  'Traffic',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Arcade',
#  'Sunshine Cleaning',
#  'Repo Man',
#  'Even Cowgirls Get the Blues',
#  'Superfights',
#  'Arbitrage',
#  'Fantastic Four',
#  'Chaos',
#  'Bamboozled',
#  'I am Sam',
#  'Spare Me',
#  'True Grit',
#  'Bad Boys',
#  'Omega Man',
#  'Mechanic, The',
#  'Invictus',
#  'My Week with Marilyn',
#  'Edward Scissorhands',
#  'Mute Witness',
#  'No Country for Old Men',
#  'Eyes Wide Shut',
#  'Phone Booth',
#  'Raising Arizona',
#  'Bound',
#  'Petulia',
#  'Bad Santa',
#  'Jaws 2',
#  'Mummy, The',
#  'Public Enemies',
#  'Hudson Hawk',
#  'Scream 3',
#  'Hudsucker Proxy, The',
#  'True Romance',
#  'Se7en',
#  'Into the Woods',
#  'Cinema Paradiso',
#  '25th Hour',
#  'Jurassic Park',
#  '17 Again',
#  'Under Fire',
#  'Silver Linings Playbook',
#  'Awakenings',
#  'Frozen',
#  'Year One',
#  'Godfather',
#  'Hackers',
#  'American History X',
#  'Bad Lieutenant',
#  'Take Shelter',
#  'Game 6',
#  'Donnie Darko',
#  'RKO 281',
#  'Frankenweenie',
#  'Freddy vs. Jason',
#  'Alien Nation',
#  'Days of Heaven',
#  'Sideways',
#  'Apt Pupil',
#  'Groundhog Day',
#  'Kill Bill Volume 1 & 2',
#  'Scary Movie 2',
#  'Titanic',
#  'Robocop',
#  'Brick',
#  'Battle of Shaker Heights, The',
#  'Final Destination 2',
#  'Stir of Echoes',
#  'Wind Chill',
#  'Hospital, The',
#  'Last Samurai, The',
#  'Anniversary Party, The',
#  'Producer, The',
#  'Black Swan',
#  'Dune',
#  'Fargo',
#  'Assignment, The',
#  'Big Fish',
#  'Blood Simple',
#  'Win Win',
#  'Dumb and Dumber',
#  'Bean',
#  'Coraline',
#  'Antitrust',
#  'Hunt for Red October, The',
#  "Harry Potter and the Sorcerer's Stone",
#  'Little Nicky',
#  'Cedar Rapids',
#  'Moon',
#  'Gone in 60 Seconds',
#  'Inglourious Basterds',
#  'Austin Powers - The Spy Who Shagged Me',
#  'Rush Hour',
#  'Equilibrium',
#  'Big',
#  'Godfather Part III, The',
#  'Blade Runner',
#  'Other Boleyn Girl, The',
#  'Blue Velvet',
#  'Wall Street',
#  'Scarface',
#  'Last Tango in Paris',
#  'Spartan',
#  'Observe and Report',
#  'Bruce Almighty',
#  'Barry Lyndon',
#  '2012',
#  'Nightmare Before Christmas, The',
#  'Blood and Wine',
#  'Boondock Saints 2: All Saints Day',
#  'Gran Torino',
#  'Gremlins 2',
#  'Ruins, The',
#  'Lost in Space',
#  'Avengers, The',
#  'Highlander: Endgame',
#  'Deep Rising',
#  'Star Wars: Attack of the Clones',
#  'Go',
#  "Mini's First Time",
#  "Charlie's Angels",
#  'Thunderheart',
#  'Ghost and the Darkness, The',
#  'Hollow Man',
#  'Analyze This',
#  'Newsies',
#  'Bull Durham',
#  '8MM',
#  'Thirteen Days',
#  'Night Time (The Poltergeist Treatment)',
#  'Pleasantville',
#  'Sweet Smell of Success',
#  'Storytelling',
#  "This Boy's Life",
#  "Miller's Crossing",
#  'Nurse Betty',
#  'Moonstruck',
#  'Mimic',
#  'Blow',
#  'Bad Teacher',
#  '500 Days of Summer',
#  'Midnight in Paris',
#  'Good Girl, The',
#  'Office Space',
#  'Jason X',
#  'Dark City',
#  'Glengarry Glen Gross',
#  'Chasing Amy',
#  'Buried',
#  'Tall in the Saddle',
#  'Philadelphia',
#  'Man Who Knew Too Much, The',
#  'Mulholland Drive',
#  'Virtuosity',
#  'Crow: City of Angels, The',
#  'Anonymous',
#  'Sphere',
#  'Cincinnati Kid, The',
#  'Cast Away',
#  'Man On Fire',
#  'Above the Law',
#  'Shadow of the Vampire',
#  'The Rage: Carrie 2',
#  'Revolutionary Road',
#  'Battle of Algiers, The',
#  'Witness',
#  'Spider-Man',
#  'Last Boy Scout, The',
#  'American Gangster',
#  'Best Exotic Marigold Hotel, The',
#  'Transformers: The Movie',
#  'Man on the Moon',
#  'TRON',
#  'Happy Feet',
#  'Beach, The',
#  'Bottle Rocket',
#  'Informant, The',
#  '12 Years a Slave',
#  'Star Wars: The Empire Strikes Back',
#  "My Best Friend's Wedding",
#  'Garden State',
#  'Carrie',
#  'Perks of Being a Wallflower, The',
#  'Darkman',
#  'New York Minute',
#  'Ali',
#  'Seventh Seal, The',
#  'X-Men Origins: Wolverine',
#  'Sex and the City',
#  'Fast Times at Ridgemont High',
#  'Cell, The',
#  'Horrible Bosses',
#  'Cold Mountain',
#  'Star Trek: First Contact',
#  'Ronin',
#  'Get Carter',
#  'Code of Silence',
#  'Jeux Interdits',
#  'Gang Related',
#  "Who's Your Daddy",
#  'Lethal Weapon 4',
#  'Italian Job, The',
#  'Next',
#  'Piano, The',
#  'Ladykillers, The',
#  'Mission Impossible',
#  'Roughshod',
#  'Boondock Saints, The',
#  'Reader, The',
#  'Erin Brockovich',
#  'Indiana Jones IV',
#  'Crazy, Stupid, Love',
#  'Matrix, The',
#  'Margaret',
#  'Zerophilia',
#  'Ghostbusters 2',
#  '187',
#  'Lost Horizon',
#  'Drive',
#  'Rise of the Planet of the Apes',
#  'We Own the Night',
#  '15 Minutes',
#  'Deer Hunter, The',
#  'Sleepy Hollow',
#  '30 Minutes or Less',
#  'Cecil B. Demented',
#  'Woodsman, The',
#  'Nine',
#  'Hellraiser',
#  'Taking Sides',
#  'Sexual Life',
#  'Tamara Drewe',
#  'American Pie',
#  'Field of Dreams',
#  'Bachelor Party',
#  'E.T.',
#  'Last Flight, The',
#  'Jacket, The',
#  'Orgy of the Dead',
#  'This is 40',
#  'Lord of the Rings: Fellowship of the Ring, The',
#  'American Beauty',
#  'Kiss of the Spider Woman',
#  'Hellboy',
#  'Relic, The',
#  'Being John Malkovich',
#  'Confessions of a Dangerous Mind',
#  'Wrestler, The',
#  'Speed',
#  'Soldier',
#  'Light Sleeper',
#  'Rear Window',
#  'Tin Men',
#  'Godzilla',
#  'Predator',
#  'Synecdoche, New York',
#  'Ni vu ni connu',
#  'Papadopoulos & Sons',
#  'Twilight: New Moon',
#  'Verdict, The',
#  'Fright Night',
#  'Fabulous Baker Boys, The',
#  'Larry Crowne',
#  'White Squall',
#  'Gattaca',
#  'Perfect Creature',
#  'Mr Brooks',
#  'Day of the Dead',
#  'Independence Day',
#  'Mission to Mars',
#  'Silver Bullet',
#  'Body Heat',
#  'Indiana Jones and the Raiders of the Lost Ark',
#  'Suspect Zero',
#  'A Most Violent Year',
#  'Last of the Mohicans, The',
#  'Speed Racer',
#  'Marty',
#  'John Q',
#  'Mariachi, El',
#  'Shawshank Redemption, The',
#  'Pokemon: Mewtwo Returns',
#  'How to Train Your Dragon 2',
#  'Bodies, Rest & Motion',
#  'Queen, The',
#  'Program, The',
#  'Twin Peaks',
#  'Mud',
#  'Sugar',
#  'Basquiat',
#  'Ghost Ship',
#  'Christ Complex',
#  'Body of Evidence',
#  'El Mariachi',
#  'Big Blue, The',
#  'Black Dahlia, The',
#  'Hangover, The',
#  'Time Machine, The',
#  'Constantine',
#  'Entrapment',
#  'Into the Wild',
#  'Sixth Sense, The',
#  "There's Something About Mary",
#  'ParaNorman',
#  "Something's Gotta Give",
#  'American, The',
#  'Two For The Money',
#  'Road, The',
#  'They',
#  'Goodfellas',
#  'Star Wars: A New Hope',
#  'Snatch',
#  'Nightbreed',
#  "Smokin' Aces",
#  'Notting Hill',
#  'Cobb',
#  'Adjustment Bureau, The',
#  'Hebrew Hammer, The',
#  'Oblivion',
#  'Fugitive, The',
#  'Ice Storm, The',
#  'Ted',
#  'True Lies',
#  'Vertigo',
#  'Les Tontons Flingueurs',
#  'Thelma & Louise',
#  'Evil Dead',
#  'Lord of Illusions',
#  'Margot at the Wedding',
#  'Manhattan Murder Mystery',
#  'Finding Nemo',
#  'I Love You Phillip Morris',
#  'Prometheus',
#  'Kill Your Darlings',
#  'Postman, The',
#  "Schindler's List",
#  'Nick of Time',
#  'Surrogates',
#  'Long Kiss Goodnight, The',
#  'Celeste & Jesse Forever',
#  'Assassins',
#  'Forrest Gump',
#  'Jurassic Park: The Lost World',
#  'Meet John Doe',
#  'Four Feathers',
#  'Cars 2',
#  'American Splendor',
#  'Last Chance Harvey',
#  'War of the Worlds',
#  'Batman Forever',
#  'Alien',
#  'Starman',
#  'Apartment, The',
#  'Life As A House',
#  "It's Complicated",
#  'Outbreak',
#  'Highlander',
#  'Dances with Wolves',
#  'Face Off',
#  'Battle: Los Angeles',
#  'Deadpool',
#  "Jacob's Ladder",
#  'Pearl Harbor',
#  'Salton Sea, The',
#  'Imaginarium of Doctor Parnassus, The',
#  'Queen of the Damned',
#  'Machete',
#  'Star Trek',
#  'Birds, The',
#  'Lake Placid',
#  'Pandorum',
#  'Taxi Driver',
#  'Only God Forgives',
#  'Defiance',
#  'Descendants, The',
#  'Rescuers Down Under, The',
#  'Majestic, The (The Bijou)',
#  'Stuntman, The',
#  'Inception',
#  'Blue Valentine',
#  'Shivers',
#  '2001: A Space Odyssey',
#  'Ninja Assassin',
#  'What Lies Beneath',
#  'Miami Vice',
#  'Hesher',
#  'Red Planet',
#  'Conan the Barbarian',
#  'Horse Whisperer, The',
#  'Wild Hogs',
#  'Made',
#  'Heavy Metal',
#  'Natural Born Killers',
#  'Clockwork Orange, A',
#  'Interstellar',
#  "My Mother Dreams the Satan's Disciples in New York",
#  'Amityville Asylum, The',
#  'Saving Private Ryan',
#  'Hard to Kill',
#  'French Connection, The',
#  'Whistleblower, The',
#  'Damned United, The',
#  'Living in Oblivion',
#  'Bounty Hunter, The',
#  'Sister Act',
#  'Monte Carlo',
#  'Airplane 2: The Sequel',
#  'Batman 2',
#  'Terminator 2: Judgement Day',
#  'JFK',
#  'Black Rain',
#  'Alien 3',
#  'Boyhood',
#  'Ordinary People',
#  'Heist',
#  'Air Force One',
#  'X-Men',
#  'Wild Bunch, The',
#  'Juno',
#  'Innerspace',
#  'Croods, The',
#  'Scott Pilgrim vs the World',
#  'Three Musketeers, The',
#  'Saint, The',
#  'Artist, The',
#  'Midnight Express',
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'Prom Night',
#  'A.I.',
#  '12',
#  'Badlands',
#  'In the Loop',
#  'eXistenZ',
#  'Planet of the Apes, The',
#  'Pineapple Express',
#  'Adaptation',
#  'Death at a Funeral',
#  "Monster's Ball",
#  'Four Rooms',
#  'White Jazz',
#  'Pet Sematary',
#  'Blade',
#  'Gandhi',
#  'Hellraiser 3: Hell on Earth',
#  'Swordfish',
#  'Water for Elephants',
#  'Harry Potter and the Chamber of Secrets',
#  'Affliction',
#  'Lord of the Rings: Return of the King',
#  'Hall Pass',
#  'Get Low',
#  'V for Vendetta',
#  'Never Been Kissed',
#  'Youth in Revolt',
#  'Devil in a Blue Dress',
#  'Sex, Lies and Videotape',
#  'Amadeus',
#  'Day the Clown Cried, The',
#  'Red Riding Hood',
#  'Death to Smoochy',
#  'Platinum Blonde',
#  'Up',
#  '8 Mile',
#  'At First Sight',
#  'Revenant, The',
#  'Troy',
#  'Pretty Woman',
#  'A Few Good Men',
#  'Zero Dark Thirty',
#  'It Happened One Night',
#  'Eagle Eye',
#  'Source Code',
#  'Surfer King, The',
#  'Rush Hour 2',
#  'Fatal Instinct',
#  'Yes Man',
#  'Quantum Project',
#  'Date Night',
#  'War Horse',
#  'Major League',
#  'Wild Things',
#  'Tombstone',
#  'Boogie Nights',
#  'Pirates of the Caribbean',
#  'Midnight Cowboy',
#  'Ghost World',
#  'Enough',
#  'Star Wars: The Phantom Menace',
#  'Pride and Prejudice',
#  'Absolute Power',
#  'Warrior',
#  'Being There',
#  '44 Inch Chest',
#  'Smashed',
#  'Funny People',
#  'Fault in Our Stars, The',
#  "It's a Wonderful Life",
#  'Rambo: First Blood II: The Mission',
#  'Malcolm X',
#  'Doors, The',
#  'Dallas Buyers Club',
#  'Jay and Silent Bob Strike Back',
#  'Courage Under Fire',
#  'Snow White and the Huntsman',
#  'State and Main',
#  "Dave Barry's Complete Guide to Guys",
#  'Duck Soup',
#  "St. Elmo's Fire",
#  'Bourne Ultimatum, The',
#  'Judge Dredd',
#  'Wanted',
#  'Manchurian Candidate, The',
#  '50-50',
#  'Romeo & Juliet',
#  'Cruel Intentions',
#  'American President, The',
#  'Land of the Dead',
#  'Kundun',
#  'Lost in Translation',
#  'Deep Cover',
#  'Snow Falling On Cedars',
#  'Final Destination',
#  'Cradle 2 the Grave',
#  "Henry's Crime",
#  'From Here to Eternity',
#  'Rock, The',
#  'Crying Game',
#  'Leviathan',
#  'Interview with the Vampire',
#  'Men in Black',
#  "Malibu's Most Wanted",
#  'I Still Know What You Did Last Summer',
#  'Tin Cup',
#  'Fight Club',
#  'Dear White People',
#  'Taking of Pelham One Two Three, The',
#  'Braveheart',
#  'Hills Have Eyes, The',
#  'All About Eve',
#  'Shampoo',
#  'Mask, The',
#  'Orphan',
#  'Insidious',
#  'Graduate, The',
#  'Starship Troopers',
#  'Almost Famous',
#  'Austin Powers - International Man of Mystery',
#  'Blind Side, The',
#  'Patriot, The',
#  'Sweeney Todd: The Demon Barber of Fleet Street',
#  'Top Gun',
#  'Hanna',
#  'Cowboys & Aliens',
#  'U Turn',
#  'Candle to Water',
#  'Change-Up, The',
#  'Dead Poets Society',
#  'Slumdog Millionaire',
#  'Rocky Horror Picture Show, The',
#  'Broken Embraces',
#  'Bad Country',
#  'Argo',
#  'Star Trek: The Motion Picture',
#  'American Sniper',
#  'Clerks',
#  'City of Joy',
#  'La La Land',
#  'Annie Hall',
#  'Klute',
#  'Watchmen',
#  'Double Indemnity',
#  "Valentine's Day",
#  'Catch Me If You Can',
#  'Angels & Demons',
#  'Pulp Fiction',
#  'Cooler, The',
#  'Star Trek: Generations',
#  'Unknown',
#  'Psycho',
#  'Unbreakable',
#  'Rachel Getting Married',
#  'Grapes of Wrath, The',
#  'His Girl Friday',
#  'Crime Spree',
#  'Departed, The',
#  'Hellraiser: Deader',
#  'Angel Eyes',
#  'Butterfly Effect, The',
#  'Save the Last Dance',
#  'Help, The',
#  'Tinker Tailor Soldier Spy',
#  'Tropic Thunder',
#  'Knocked Up',
#  'Mirrors',
#  'Perfect World, A',
#  'Full Metal Jacket',
#  '12 Monkeys',
#  'Officer and a Gentleman, An',
#  'Django Unchained',
#  'Out of Sight',
#  'Sleepless in Seattle',
#  'Cherry Falls',
#  'Dog Day Afternoon',
#  'Jurassic Park III',
#  'Losers, The',
#  'TRON: Legacy',
#  'Back to the Future II & III',
#  'Autumn in New York',
#  'Proposal, The',
#  'Custody',
#  'Bachelor Party, The',
#  'Easy A',
#  'Fighter, The',
#  'Heathers',
#  'Tourist, The',
#  'Gravity',
#  'Ghost Rider',
#  'Detroit Rock City',
#  'Mr Deeds Goes to Town',
#  'Meet Joe Black',
#  'Up in the Air',
#  'Arthur',
#  'Dark Knight Rises, The',
#  'Jerry Maguire',
#  'Village, The',
#  'Debt, The',
#  'Avatar',
#  'Neverending Story, The',
#  'Bonnie and Clyde',
#  'Wonder Boys',
#  'Nashville',
#  'Jackie Brown',
#  'Thunderbirds',
#  'Remember Me',
#  'Anastasia',
#  'From Dusk Till Dawn',
#  'Donnie Brasco',
#  'Evil Dead II: Dead by Dawn',
#  'Men Who Stare at Goats, The',
#  'Roommate, The',
#  'August: Osage County',
#  'Memento',
#  'Collateral',
#  'Leaving Las Vegas',
#  'Aladdin',
#  'Alien vs. Predator',
#  'Citizen Kane',
#  'How to Train Your Dragon',
#  'Star Wars: The Force Awakens',
#  'Kids',
#  'Anna Karenina',
#  'Dark Knight, The',
#  'Abyss, The',
#  'Lincoln',
#  'Six Degrees of Separation',
#  'Killing Zoe',
#  'Harry Potter and the Half-Blood Prince',
#  'Commando',
#  'Haunting, The',
#  'King of Comedy, The',
#  'Grosse Point Blank',
#  'Limitless',
#  'Fear and Loathing in Las Vegas',
#  'Monkeybone',
#  'Contact',
#  'Lord of the Rings: The Two Towers',
#  'Wild Things: Diamonds in the Rough',
#  'Sting, The',
#  'Return of the Apes',
#  'Kramer vs Kramer',
#  'Belle',
#  'Addams Family, The',
#  'Fantastic Mr Fox',
#  'Changeling',
#  'Hitchcock',
#  'Whiteout',
#  'Crow, The',
#  'When a Stranger Calls',
#  'Frozen River',
#  "Avventura, L' (The Adventure)",
#  'Life',
#  'Private Life of Sherlock Holmes, The',
#  'Mumford',
#  '1492: Conquest of Paradise',
#  'After School Special',
#  'Marley & Me',
#  'Believer, The',
#  'Adventures of Buckaroo Banzai Across the Eighth Dimension, The',
#  'Hotel Rwanda',
#  'Hellraiser: Hellseeker',
#  'Book of Eli, The',
#  'Dragonslayer',
#  'Harry Potter and the Goblet of Fire',
#  'Batman',
#  'Executive Decision',
#  'Ringu',
#  'Backdraft',
#  'Case 39',
#  'O Brother Where Art Thou?',
#  "Ocean's Eleven",
#  'Henry Fool',
#  '127 Hours',
#  'Indiana Jones and the Temple of Doom',
#  'Semi-Pro',
#  'Ed TV',
#  'Minority Report',
#  'Three Kings',
#  'Cider House Rules, The',
#  'Beavis and Butt-head Do America',
#  'Star Trek: Nemesis',
#  'Five Easy Pieces',
#  'Clueless',
#  'Fright Night (1985)',
#  'Armageddon',
#  'Megamind',
#  'Rushmore',
#  'Reindeer Games',
#  'Dark Star',
#  'Fracture',
#  'Ghost',
#  'Mystery Men',
#  'G.I. Jane',
#  'Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#  'Collateral Damage',
#  "April Fool's Day",
#  'Drive Angry',
#  'Jimmy and Judy',
#  'Paul',
#  'Hellboy 2: The Golden Army',
#  'Grifters, The',
#  'Birdman',
#  'Rise of the Guardians',
#  'Freaked',
#  'Airplane',
#  'Replacements, The',
#  'When Harry Met Sally',
#  'Music of the Heart',
#  'Get Shorty',
#  'Life of Pi',
#  'Three Men and a Baby',
#  'Law Abiding Citizen',
#  'Tremors',
#  'Hancock',
#  "I'll Do Anything",
#  'Shining, The',
#  'Thor',
#  'Twins',
#  'American Shaolin: King of Kickboxers II',
#  'Sugar and Spice',
#  'Indiana Jones and the Last Crusade',
#  'Mission Impossible II',
#  'American Outlaws',
#  'Kids Are All Right, The',
#  'Man in the Iron Mask',
#  'Spanglish',
#  'Legally Blonde',
#  'Napoleon Dynamite',
#  'Saw',
#  'Buffy the Vampire Slayer',
#  "All the President's Men",
#  'Fair Game',
#  'What About Bob?',
#  "Ferris Bueller's Day Off",
#  'While She Was Out',
#  'Hellbound: Hellraiser II',
#  'Shallow Grave',
#  'Batman Begins',
#  'Un Singe en Hiver',
#  'Rust and Bone',
#  'Creation',
#  'Lost Highway',
#  'Sling Blade',
#  'Raging Bull',
#  'Bourne Supremacy, The',
#  'Searchers, The',
#  'Confidence',
#  'Batman and Robin',
#  ...]

# %%
vars(films.search_movie(titles[10])[10])
# Out:
# {'_Container__role': None,
#  '_roleClass': imdb.Character.Character,
#  '_roleIsPerson': False,
#  'accessSystem': 's3',
#  'charactersRefs': {},
#  'current_info': [],
#  'data': {'adult': False,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'kind': 'movie',
#   'movieID': 90605,
#   'original title': 'Aliens',
#   'runtimes': 137,
#   'startYear': 1986,
#   'title': 'Aliens'},
#  'infoset2keys': {},
#  'key2infoset': {},
#  'keys_tomodify': {'alternate versions': None,
#   'business': None,
#   'crazy credits': None,
#   'dvd': None,
#   'faqs': None,
#   'goofs': None,
#   'laserdisc': None,
#   'news': None,
#   'plot': None,
#   'quotes': None,
#   'soundtrack': None,
#   'supplements': None,
#   'trivia': None,
#   'video review': None},
#  'modFunct': <function imdb.utils.modClearRefs>,
#  'movieID': 90605,
#  'myID': None,
#  'myTitle': '',
#  'namesRefs': {},
#  'notes': '',
#  'titlesRefs': {}}

# %%
films.search_movie(titles[10])[0].data
# Out:
# {'adult': False,
#  'genres': 'Short',
#  'kind': 'short',
#  'movieID': 7285968,
#  'original title': 'Aliens',
#  'runtimes': 23,
#  'startYear': 2017,
#  'title': 'Aliens'}

# %%
aliensID
# Out:
# 90605

# %%
net = i()
sorted(net.get_movie(aliensID).data['genres'])
# Out:
# ['Action', 'Adventure', 'Sci-Fi', 'Thriller']

# %%
print(net.title2imdbID(titles[10].lower()))
# Out:
# None

# %%
top = net.get_top250_movies()

# %%
top[0].data
# Out:
# {'kind': 'movie',
#  'rating': 9.2,
#  'title': 'The Shawshank Redemption',
#  'top 250 rank': 1,
#  'votes': 1925506,
#  'year': 1994}

# %%
top250 = [x.data for x in top]
imdb250 = pd.DataFrame()
for x in top250:
    imdb250 = imdb250.append(x, ignore_index=True)
imdb250
# Out:
#       kind  rating                                              title  \
# 0    movie     9.2                           The Shawshank Redemption
# 1    movie     9.2                                      The Godfather
# 2    movie     9.0                             The Godfather: Part II
# 3    movie     9.0                                    The Dark Knight
# 4    movie     8.9                                       12 Angry Men
# 5    movie     8.9                                   Schindler's List
# 6    movie     8.9      The Lord of the Rings: The Return of the King
# 7    movie     8.9                                       Pulp Fiction
# 8    movie     8.8                     The Good, the Bad and the Ugly
# 9    movie     8.8                                         Fight Club
# 10   movie     8.8  The Lord of the Rings: The Fellowship of the Ring
# 11   movie     8.7                                       Forrest Gump
# 12   movie     8.7     Star Wars: Episode V - The Empire Strikes Back
# 13   movie     8.7                                          Inception
# 14   movie     8.7              The Lord of the Rings: The Two Towers
# 15   movie     8.7                    One Flew Over the Cuckoo's Nest
# 16   movie     8.7                                         Goodfellas
# 17   movie     8.7                                         The Matrix
# 18   movie     8.6                                      Seven Samurai
# 19   movie     8.6                 Star Wars: Episode IV - A New Hope
# 20   movie     8.6                                        City of God
# 21   movie     8.6                                              Se7en
# 22   movie     8.6                           The Silence of the Lambs
# 23   movie     8.6                              It's a Wonderful Life
# 24   movie     8.6                                  Life Is Beautiful
# 25   movie     8.6                                 The Usual Suspects
# 26   movie     8.5                             Léon: The Professional
# 27   movie     8.5                                      Spirited Away
# 28   movie     8.5                                Saving Private Ryan
# 29   movie     8.5                                       Interstellar
# ..     ...     ...                                                ...
# 220  movie     8.0                                     Monsters, Inc.
# 221  movie     8.0                                         Diabolique
# 222  movie     8.0                                         Paper Moon
# 223  movie     8.0                                       Donnie Darko
# 224  movie     8.0                                       Barry Lyndon
# 225  movie     8.0                                             Gandhi
# 226  movie     8.0                                      Touch of Evil
# 227  movie     8.0                                     The Terminator
# 228  movie     8.0                                      Groundhog Day
# 229  movie     8.0                                           La Haine
# 230  movie     8.0                                   The Wizard of Oz
# 231  movie     8.0                                         Annie Hall
# 232  movie     8.0                               The Bourne Ultimatum
# 233  movie     8.0                                                 8½
# 234  movie     8.0                                 Dead Poets Society
# 235  movie     8.0                                               Jaws
# 236  movie     8.0                                           The Help
# 237  movie     8.0                        The Best Years of Our Lives
# 238  movie     8.0                               In the Mood for Love
# 239  movie     8.0                                   Infernal Affairs
# 240  movie     8.0                                     Twelve Monkeys
# 241  movie     8.0                                       Paris, Texas
# 242  movie     8.0                                 Gangs of Wasseypur
# 243  movie     8.0                               Beauty and the Beast
# 244  movie     8.0                                           Drishyam
# 245  movie     8.0                              The Battle of Algiers
# 246  movie     8.0  Pirates of the Caribbean: The Curse of the Bla...
# 247  movie     8.0                                      Before Sunset
# 248  movie     8.0                                     The Handmaiden
# 249  movie     8.0                                                 PK
#
#      top 250 rank      votes    year
# 0             1.0  1925506.0  1994.0
# 1             2.0  1316565.0  1972.0
# 2             3.0   909320.0  1974.0
# 3             4.0  1896819.0  2008.0
# 4             5.0   532202.0  1957.0
# 5             6.0   991692.0  1993.0
# 6             7.0  1374489.0  2003.0
# 7             8.0  1504244.0  1994.0
# 8             9.0   570260.0  1966.0
# 9            10.0  1541836.0  1999.0
# 10           11.0  1394044.0  2001.0
# 11           12.0  1456603.0  1994.0
# 12           13.0   967938.0  1980.0
# 13           14.0  1684339.0  2010.0
# 14           15.0  1244261.0  2002.0
# 15           16.0   767606.0  1975.0
# 16           17.0   829780.0  1990.0
# 17           18.0  1383169.0  1999.0
# 18           19.0   259668.0  1954.0
# 19           20.0  1040085.0  1977.0
# 20           21.0   598311.0  2002.0
# 21           22.0  1173955.0  1995.0
# 22           23.0  1027559.0  1991.0
# 23           24.0   322788.0  1946.0
# 24           25.0   497481.0  1997.0
# 25           26.0   839896.0  1995.0
# 26           27.0   839031.0  1994.0
# 27           28.0   498404.0  2001.0
# 28           29.0  1014010.0  1998.0
# 29           30.0  1151580.0  2014.0
# ..            ...        ...     ...
# 220         221.0   675558.0  2001.0
# 221         222.0    49816.0  1955.0
# 222         223.0    30506.0  1973.0
# 223         224.0   655073.0  2001.0
# 224         225.0   118238.0  1975.0
# 225         226.0   193709.0  1982.0
# 226         227.0    82996.0  1958.0
# 227         228.0   677317.0  1984.0
# 228         229.0   502205.0  1993.0
# 229         230.0   120559.0  1995.0
# 230         231.0   327379.0  1939.0
# 231         232.0   222114.0  1977.0
# 232         233.0   551676.0  2007.0
# 233         234.0    90650.0  1963.0
# 234         235.0   322971.0  1989.0
# 235         236.0   471010.0  1975.0
# 236         237.0   363716.0  2011.0
# 237         238.0    47144.0  1946.0
# 238         239.0    92488.0  2000.0
# 239         240.0   104316.0  2002.0
# 240         241.0   514201.0  1995.0
# 241         242.0    62734.0  1984.0
# 242         243.0    59199.0  2012.0
# 243         244.0   359659.0  1991.0
# 244         245.0    45215.0  2015.0
# 245         246.0    43827.0  1966.0
# 246         247.0   907295.0  2003.0
# 247         248.0   188437.0  2004.0
# 248         249.0    57140.0  2016.0
# 249         250.0   118382.0  2014.0
#
# [250 rows x 6 columns]

# %%
imdb250.title
matches = 0
for x in titles:
    if x in imdb250.title.values:
        matches += 1
print(matches)
# Out:
# 78

# %%
titles
# Out:
# ['Invention of Lying, The',
#  'Machine Gun Preacher',
#  "Jennifer's Body",
#  'Cellular',
#  'Rambling Rose',
#  'Someone To Watch Over Me',
#  'Beasts of the Southern Wild',
#  'Family Man, The',
#  'Trainspotting',
#  'Antz',
#  'Aliens',
#  'Martha Marcy May Marlene',
#  'Birthday Girl',
#  'Sherlock Holmes',
#  'I, Robot',
#  'Fletch',
#  "Ocean's Twelve",
#  'Runaway Bride',
#  'Little Athens',
#  'Resident Evil',
#  "All the King's Men",
#  'Foxcatcher',
#  'Liar Liar',
#  'Despicable Me 2',
#  'South Park',
#  'Misery',
#  'Wild Wild West',
#  'White Ribbon, The',
#  'Scream 2',
#  'White Christmas',
#  'Big Eyes',
#  "King's Speech, The",
#  'Bodyguard',
#  'Les Miserables',
#  'How to Lose Friends & Alienate People',
#  'Ghostbusters',
#  'Chinatown',
#  'Beloved',
#  'Terminator',
#  'Basic Instinct',
#  'Jennifer Eight',
#  'Flash Gordon',
#  'Bad Dreams',
#  'Taking Lives',
#  'Gothika',
#  'Frances',
#  'Next Friday',
#  'Copycat',
#  'Pet Sematary II',
#  'Game, The',
#  'Shifty',
#  'Erik the Viking',
#  'Amelia',
#  'Die Hard 2',
#  'Lock, Stock and Two Smoking Barrels',
#  'Toy Story',
#  'Matchstick Men',
#  '10 Things I Hate About You',
#  'Broadcast News',
#  'Timber Falls',
#  'Escape From L.A.',
#  "Cirque du Freak: The Vampire's Assistant",
#  'All About Steve',
#  'Event Horizon',
#  'Bringing Out the Dead',
#  'American Hustle',
#  'Gamer',
#  'Drop Dead Gorgeous',
#  'As Good As It Gets',
#  'Day the Earth Stood Still, The',
#  'I Spit on Your Grave',
#  'Box, The',
#  'Flight',
#  'Elizabeth: The Golden Age',
#  'Insomnia',
#  'Apollo 13',
#  'Honeydripper',
#  "Hitchhiker's Guide to the Galaxy, The",
#  'Things My Father Never Taught Me, The',
#  'Barton Fink',
#  'Peggy Sue Got Married',
#  'Escape From New York',
#  'Robin Hood: Prince of Thieves',
#  'Crouching Tiger, Hidden Dragon',
#  'Harry Potter and the Deathly Hallows Part 1',
#  'Lion King, The',
#  'Human Nature',
#  'Mary Poppins',
#  'Life of David Gale, The',
#  'Point Break',
#  'Rocky',
#  'American Madness',
#  'Supergirl',
#  'Casablanca',
#  'Siege, The',
#  'Sessions, The',
#  'Babel',
#  'Ticker',
#  'Frankenstein',
#  'Shakespeare in Love',
#  'Real Genius',
#  'Agnes of God',
#  'Frequency',
#  'Wolf of Wall Street, The',
#  'Girl with the Dragon Tattoo, The',
#  'Apocalypse Now',
#  'Rush',
#  'Jade',
#  'Passion of Joan of Arc, The',
#  'Walk to Remember, A',
#  'High Fidelity',
#  'Margin Call',
#  'Drag Me to Hell',
#  'Last Station, The',
#  'Arctic Blue',
#  'Fruitvale Station',
#  'Kafka',
#  'Slither',
#  'Tristan and Isolde',
#  'Clash of the Titans',
#  'Miracle Worker, The',
#  'So I Married an Axe Murderer',
#  'TMNT',
#  'Pianist, The',
#  'Eastern Promises',
#  'Limey, The',
#  'World is not Enough, The',
#  'Nightmare on Elm Street, A',
#  'Serenity',
#  'Brazil',
#  'American Graffiti',
#  'Cube',
#  'Happy Birthday, Wanda June',
#  'Gremlins',
#  'Shrek the Third',
#  'Election',
#  'Thing, The',
#  'Jaws',
#  'Broken Arrow',
#  'Colombiana',
#  'Kate & Leopold',
#  'Labyrinth',
#  'Matrix Reloaded, The',
#  'Get on Up',
#  'Moonrise Kingdom',
#  'Feast',
#  'American Werewolf in London',
#  'Benny & Joon',
#  'Burlesque',
#  'Batman Returns',
#  'Alone in the Dark',
#  'Break',
#  'Harold and Kumar Go to White Castle',
#  'My Girl',
#  'Die Hard',
#  'Terminator Salvation',
#  'Crow Salvation, The',
#  'Rebel Without A Cause',
#  '.DS_',
#  'Sunset Blvd.',
#  'Labor of Love',
#  'Amour',
#  'Unforgiven',
#  'Charade',
#  'Friday the 13th Part VIII: Jason Takes Manhattan',
#  'Sneakers',
#  'Arsenic and Old Lace',
#  'Saving Mr. Banks',
#  'Who Framed Roger Rabbit?',
#  'Metro',
#  'Croupier',
#  'Bad Day at Black Rock',
#  'L.A. Confidential',
#  'Distinguished Gentleman, The',
#  'Shame',
#  'Punch-Drunk Love',
#  'Deception',
#  'Valkyrie',
#  'Ides of March, The',
#  'Crash',
#  'Diner',
#  'Inventing the Abbotts',
#  'Mr Blandings Builds His Dream House',
#  'Swingers',
#  'Usual Suspects, The',
#  'Strangers on a Train',
#  'Power of One, The',
#  'Getaway, The',
#  'Total Recall',
#  'Withnail and I',
#  'Avengers, The (2012)',
#  'Bling Ring, The',
#  'Mulan',
#  'Pacifier, The',
#  'King Kong',
#  'Lone Star',
#  'Looper',
#  'A Serious Man',
#  'Blade II',
#  'Jane Eyre',
#  'In the Bedroom',
#  'Hannibal',
#  'Hostage',
#  'Super 8',
#  'No Strings Attached',
#  'Disturbia',
#  'Burn After Reading',
#  "Mr. Holland's Opus",
#  'Wall Street: Money Never Sleeps',
#  'Cliffhanger',
#  'Obsessed',
#  'Eight Legged Freaks',
#  "Devil's Advocate",
#  'Max Payne',
#  'Elephant Man, The',
#  'Wall-E',
#  'Pariah',
#  'Bonfire of the Vanities',
#  'After.Life',
#  'Incredibles, The',
#  'Insider, The',
#  'Man Trouble',
#  'Traffic',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Arcade',
#  'Sunshine Cleaning',
#  'Repo Man',
#  'Even Cowgirls Get the Blues',
#  'Superfights',
#  'Arbitrage',
#  'Fantastic Four',
#  'Chaos',
#  'Bamboozled',
#  'I am Sam',
#  'Spare Me',
#  'True Grit',
#  'Bad Boys',
#  'Omega Man',
#  'Mechanic, The',
#  'Invictus',
#  'My Week with Marilyn',
#  'Edward Scissorhands',
#  'Mute Witness',
#  'No Country for Old Men',
#  'Eyes Wide Shut',
#  'Phone Booth',
#  'Raising Arizona',
#  'Bound',
#  'Petulia',
#  'Bad Santa',
#  'Jaws 2',
#  'Mummy, The',
#  'Public Enemies',
#  'Hudson Hawk',
#  'Scream 3',
#  'Hudsucker Proxy, The',
#  'True Romance',
#  'Se7en',
#  'Into the Woods',
#  'Cinema Paradiso',
#  '25th Hour',
#  'Jurassic Park',
#  '17 Again',
#  'Under Fire',
#  'Silver Linings Playbook',
#  'Awakenings',
#  'Frozen',
#  'Year One',
#  'Godfather',
#  'Hackers',
#  'American History X',
#  'Bad Lieutenant',
#  'Take Shelter',
#  'Game 6',
#  'Donnie Darko',
#  'RKO 281',
#  'Frankenweenie',
#  'Freddy vs. Jason',
#  'Alien Nation',
#  'Days of Heaven',
#  'Sideways',
#  'Apt Pupil',
#  'Groundhog Day',
#  'Kill Bill Volume 1 & 2',
#  'Scary Movie 2',
#  'Titanic',
#  'Robocop',
#  'Brick',
#  'Battle of Shaker Heights, The',
#  'Final Destination 2',
#  'Stir of Echoes',
#  'Wind Chill',
#  'Hospital, The',
#  'Last Samurai, The',
#  'Anniversary Party, The',
#  'Producer, The',
#  'Black Swan',
#  'Dune',
#  'Fargo',
#  'Assignment, The',
#  'Big Fish',
#  'Blood Simple',
#  'Win Win',
#  'Dumb and Dumber',
#  'Bean',
#  'Coraline',
#  'Antitrust',
#  'Hunt for Red October, The',
#  "Harry Potter and the Sorcerer's Stone",
#  'Little Nicky',
#  'Cedar Rapids',
#  'Moon',
#  'Gone in 60 Seconds',
#  'Inglourious Basterds',
#  'Austin Powers - The Spy Who Shagged Me',
#  'Rush Hour',
#  'Equilibrium',
#  'Big',
#  'Godfather Part III, The',
#  'Blade Runner',
#  'Other Boleyn Girl, The',
#  'Blue Velvet',
#  'Wall Street',
#  'Scarface',
#  'Last Tango in Paris',
#  'Spartan',
#  'Observe and Report',
#  'Bruce Almighty',
#  'Barry Lyndon',
#  '2012',
#  'Nightmare Before Christmas, The',
#  'Blood and Wine',
#  'Boondock Saints 2: All Saints Day',
#  'Gran Torino',
#  'Gremlins 2',
#  'Ruins, The',
#  'Lost in Space',
#  'Avengers, The',
#  'Highlander: Endgame',
#  'Deep Rising',
#  'Star Wars: Attack of the Clones',
#  'Go',
#  "Mini's First Time",
#  "Charlie's Angels",
#  'Thunderheart',
#  'Ghost and the Darkness, The',
#  'Hollow Man',
#  'Analyze This',
#  'Newsies',
#  'Bull Durham',
#  '8MM',
#  'Thirteen Days',
#  'Night Time (The Poltergeist Treatment)',
#  'Pleasantville',
#  'Sweet Smell of Success',
#  'Storytelling',
#  "This Boy's Life",
#  "Miller's Crossing",
#  'Nurse Betty',
#  'Moonstruck',
#  'Mimic',
#  'Blow',
#  'Bad Teacher',
#  '500 Days of Summer',
#  'Midnight in Paris',
#  'Good Girl, The',
#  'Office Space',
#  'Jason X',
#  'Dark City',
#  'Glengarry Glen Gross',
#  'Chasing Amy',
#  'Buried',
#  'Tall in the Saddle',
#  'Philadelphia',
#  'Man Who Knew Too Much, The',
#  'Mulholland Drive',
#  'Virtuosity',
#  'Crow: City of Angels, The',
#  'Anonymous',
#  'Sphere',
#  'Cincinnati Kid, The',
#  'Cast Away',
#  'Man On Fire',
#  'Above the Law',
#  'Shadow of the Vampire',
#  'The Rage: Carrie 2',
#  'Revolutionary Road',
#  'Battle of Algiers, The',
#  'Witness',
#  'Spider-Man',
#  'Last Boy Scout, The',
#  'American Gangster',
#  'Best Exotic Marigold Hotel, The',
#  'Transformers: The Movie',
#  'Man on the Moon',
#  'TRON',
#  'Happy Feet',
#  'Beach, The',
#  'Bottle Rocket',
#  'Informant, The',
#  '12 Years a Slave',
#  'Star Wars: The Empire Strikes Back',
#  "My Best Friend's Wedding",
#  'Garden State',
#  'Carrie',
#  'Perks of Being a Wallflower, The',
#  'Darkman',
#  'New York Minute',
#  'Ali',
#  'Seventh Seal, The',
#  'X-Men Origins: Wolverine',
#  'Sex and the City',
#  'Fast Times at Ridgemont High',
#  'Cell, The',
#  'Horrible Bosses',
#  'Cold Mountain',
#  'Star Trek: First Contact',
#  'Ronin',
#  'Get Carter',
#  'Code of Silence',
#  'Jeux Interdits',
#  'Gang Related',
#  "Who's Your Daddy",
#  'Lethal Weapon 4',
#  'Italian Job, The',
#  'Next',
#  'Piano, The',
#  'Ladykillers, The',
#  'Mission Impossible',
#  'Roughshod',
#  'Boondock Saints, The',
#  'Reader, The',
#  'Erin Brockovich',
#  'Indiana Jones IV',
#  'Crazy, Stupid, Love',
#  'Matrix, The',
#  'Margaret',
#  'Zerophilia',
#  'Ghostbusters 2',
#  '187',
#  'Lost Horizon',
#  'Drive',
#  'Rise of the Planet of the Apes',
#  'We Own the Night',
#  '15 Minutes',
#  'Deer Hunter, The',
#  'Sleepy Hollow',
#  '30 Minutes or Less',
#  'Cecil B. Demented',
#  'Woodsman, The',
#  'Nine',
#  'Hellraiser',
#  'Taking Sides',
#  'Sexual Life',
#  'Tamara Drewe',
#  'American Pie',
#  'Field of Dreams',
#  'Bachelor Party',
#  'E.T.',
#  'Last Flight, The',
#  'Jacket, The',
#  'Orgy of the Dead',
#  'This is 40',
#  'Lord of the Rings: Fellowship of the Ring, The',
#  'American Beauty',
#  'Kiss of the Spider Woman',
#  'Hellboy',
#  'Relic, The',
#  'Being John Malkovich',
#  'Confessions of a Dangerous Mind',
#  'Wrestler, The',
#  'Speed',
#  'Soldier',
#  'Light Sleeper',
#  'Rear Window',
#  'Tin Men',
#  'Godzilla',
#  'Predator',
#  'Synecdoche, New York',
#  'Ni vu ni connu',
#  'Papadopoulos & Sons',
#  'Twilight: New Moon',
#  'Verdict, The',
#  'Fright Night',
#  'Fabulous Baker Boys, The',
#  'Larry Crowne',
#  'White Squall',
#  'Gattaca',
#  'Perfect Creature',
#  'Mr Brooks',
#  'Day of the Dead',
#  'Independence Day',
#  'Mission to Mars',
#  'Silver Bullet',
#  'Body Heat',
#  'Indiana Jones and the Raiders of the Lost Ark',
#  'Suspect Zero',
#  'A Most Violent Year',
#  'Last of the Mohicans, The',
#  'Speed Racer',
#  'Marty',
#  'John Q',
#  'Mariachi, El',
#  'Shawshank Redemption, The',
#  'Pokemon: Mewtwo Returns',
#  'How to Train Your Dragon 2',
#  'Bodies, Rest & Motion',
#  'Queen, The',
#  'Program, The',
#  'Twin Peaks',
#  'Mud',
#  'Sugar',
#  'Basquiat',
#  'Ghost Ship',
#  'Christ Complex',
#  'Body of Evidence',
#  'El Mariachi',
#  'Big Blue, The',
#  'Black Dahlia, The',
#  'Hangover, The',
#  'Time Machine, The',
#  'Constantine',
#  'Entrapment',
#  'Into the Wild',
#  'Sixth Sense, The',
#  "There's Something About Mary",
#  'ParaNorman',
#  "Something's Gotta Give",
#  'American, The',
#  'Two For The Money',
#  'Road, The',
#  'They',
#  'Goodfellas',
#  'Star Wars: A New Hope',
#  'Snatch',
#  'Nightbreed',
#  "Smokin' Aces",
#  'Notting Hill',
#  'Cobb',
#  'Adjustment Bureau, The',
#  'Hebrew Hammer, The',
#  'Oblivion',
#  'Fugitive, The',
#  'Ice Storm, The',
#  'Ted',
#  'True Lies',
#  'Vertigo',
#  'Les Tontons Flingueurs',
#  'Thelma & Louise',
#  'Evil Dead',
#  'Lord of Illusions',
#  'Margot at the Wedding',
#  'Manhattan Murder Mystery',
#  'Finding Nemo',
#  'I Love You Phillip Morris',
#  'Prometheus',
#  'Kill Your Darlings',
#  'Postman, The',
#  "Schindler's List",
#  'Nick of Time',
#  'Surrogates',
#  'Long Kiss Goodnight, The',
#  'Celeste & Jesse Forever',
#  'Assassins',
#  'Forrest Gump',
#  'Jurassic Park: The Lost World',
#  'Meet John Doe',
#  'Four Feathers',
#  'Cars 2',
#  'American Splendor',
#  'Last Chance Harvey',
#  'War of the Worlds',
#  'Batman Forever',
#  'Alien',
#  'Starman',
#  'Apartment, The',
#  'Life As A House',
#  "It's Complicated",
#  'Outbreak',
#  'Highlander',
#  'Dances with Wolves',
#  'Face Off',
#  'Battle: Los Angeles',
#  'Deadpool',
#  "Jacob's Ladder",
#  'Pearl Harbor',
#  'Salton Sea, The',
#  'Imaginarium of Doctor Parnassus, The',
#  'Queen of the Damned',
#  'Machete',
#  'Star Trek',
#  'Birds, The',
#  'Lake Placid',
#  'Pandorum',
#  'Taxi Driver',
#  'Only God Forgives',
#  'Defiance',
#  'Descendants, The',
#  'Rescuers Down Under, The',
#  'Majestic, The (The Bijou)',
#  'Stuntman, The',
#  'Inception',
#  'Blue Valentine',
#  'Shivers',
#  '2001: A Space Odyssey',
#  'Ninja Assassin',
#  'What Lies Beneath',
#  'Miami Vice',
#  'Hesher',
#  'Red Planet',
#  'Conan the Barbarian',
#  'Horse Whisperer, The',
#  'Wild Hogs',
#  'Made',
#  'Heavy Metal',
#  'Natural Born Killers',
#  'Clockwork Orange, A',
#  'Interstellar',
#  "My Mother Dreams the Satan's Disciples in New York",
#  'Amityville Asylum, The',
#  'Saving Private Ryan',
#  'Hard to Kill',
#  'French Connection, The',
#  'Whistleblower, The',
#  'Damned United, The',
#  'Living in Oblivion',
#  'Bounty Hunter, The',
#  'Sister Act',
#  'Monte Carlo',
#  'Airplane 2: The Sequel',
#  'Batman 2',
#  'Terminator 2: Judgement Day',
#  'JFK',
#  'Black Rain',
#  'Alien 3',
#  'Boyhood',
#  'Ordinary People',
#  'Heist',
#  'Air Force One',
#  'X-Men',
#  'Wild Bunch, The',
#  'Juno',
#  'Innerspace',
#  'Croods, The',
#  'Scott Pilgrim vs the World',
#  'Three Musketeers, The',
#  'Saint, The',
#  'Artist, The',
#  'Midnight Express',
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'Prom Night',
#  'A.I.',
#  '12',
#  'Badlands',
#  'In the Loop',
#  'eXistenZ',
#  'Planet of the Apes, The',
#  'Pineapple Express',
#  'Adaptation',
#  'Death at a Funeral',
#  "Monster's Ball",
#  'Four Rooms',
#  'White Jazz',
#  'Pet Sematary',
#  'Blade',
#  'Gandhi',
#  'Hellraiser 3: Hell on Earth',
#  'Swordfish',
#  'Water for Elephants',
#  'Harry Potter and the Chamber of Secrets',
#  'Affliction',
#  'Lord of the Rings: Return of the King',
#  'Hall Pass',
#  'Get Low',
#  'V for Vendetta',
#  'Never Been Kissed',
#  'Youth in Revolt',
#  'Devil in a Blue Dress',
#  'Sex, Lies and Videotape',
#  'Amadeus',
#  'Day the Clown Cried, The',
#  'Red Riding Hood',
#  'Death to Smoochy',
#  'Platinum Blonde',
#  'Up',
#  '8 Mile',
#  'At First Sight',
#  'Revenant, The',
#  'Troy',
#  'Pretty Woman',
#  'A Few Good Men',
#  'Zero Dark Thirty',
#  'It Happened One Night',
#  'Eagle Eye',
#  'Source Code',
#  'Surfer King, The',
#  'Rush Hour 2',
#  'Fatal Instinct',
#  'Yes Man',
#  'Quantum Project',
#  'Date Night',
#  'War Horse',
#  'Major League',
#  'Wild Things',
#  'Tombstone',
#  'Boogie Nights',
#  'Pirates of the Caribbean',
#  'Midnight Cowboy',
#  'Ghost World',
#  'Enough',
#  'Star Wars: The Phantom Menace',
#  'Pride and Prejudice',
#  'Absolute Power',
#  'Warrior',
#  'Being There',
#  '44 Inch Chest',
#  'Smashed',
#  'Funny People',
#  'Fault in Our Stars, The',
#  "It's a Wonderful Life",
#  'Rambo: First Blood II: The Mission',
#  'Malcolm X',
#  'Doors, The',
#  'Dallas Buyers Club',
#  'Jay and Silent Bob Strike Back',
#  'Courage Under Fire',
#  'Snow White and the Huntsman',
#  'State and Main',
#  "Dave Barry's Complete Guide to Guys",
#  'Duck Soup',
#  "St. Elmo's Fire",
#  'Bourne Ultimatum, The',
#  'Judge Dredd',
#  'Wanted',
#  'Manchurian Candidate, The',
#  '50-50',
#  'Romeo & Juliet',
#  'Cruel Intentions',
#  'American President, The',
#  'Land of the Dead',
#  'Kundun',
#  'Lost in Translation',
#  'Deep Cover',
#  'Snow Falling On Cedars',
#  'Final Destination',
#  'Cradle 2 the Grave',
#  "Henry's Crime",
#  'From Here to Eternity',
#  'Rock, The',
#  'Crying Game',
#  'Leviathan',
#  'Interview with the Vampire',
#  'Men in Black',
#  "Malibu's Most Wanted",
#  'I Still Know What You Did Last Summer',
#  'Tin Cup',
#  'Fight Club',
#  'Dear White People',
#  'Taking of Pelham One Two Three, The',
#  'Braveheart',
#  'Hills Have Eyes, The',
#  'All About Eve',
#  'Shampoo',
#  'Mask, The',
#  'Orphan',
#  'Insidious',
#  'Graduate, The',
#  'Starship Troopers',
#  'Almost Famous',
#  'Austin Powers - International Man of Mystery',
#  'Blind Side, The',
#  'Patriot, The',
#  'Sweeney Todd: The Demon Barber of Fleet Street',
#  'Top Gun',
#  'Hanna',
#  'Cowboys & Aliens',
#  'U Turn',
#  'Candle to Water',
#  'Change-Up, The',
#  'Dead Poets Society',
#  'Slumdog Millionaire',
#  'Rocky Horror Picture Show, The',
#  'Broken Embraces',
#  'Bad Country',
#  'Argo',
#  'Star Trek: The Motion Picture',
#  'American Sniper',
#  'Clerks',
#  'City of Joy',
#  'La La Land',
#  'Annie Hall',
#  'Klute',
#  'Watchmen',
#  'Double Indemnity',
#  "Valentine's Day",
#  'Catch Me If You Can',
#  'Angels & Demons',
#  'Pulp Fiction',
#  'Cooler, The',
#  'Star Trek: Generations',
#  'Unknown',
#  'Psycho',
#  'Unbreakable',
#  'Rachel Getting Married',
#  'Grapes of Wrath, The',
#  'His Girl Friday',
#  'Crime Spree',
#  'Departed, The',
#  'Hellraiser: Deader',
#  'Angel Eyes',
#  'Butterfly Effect, The',
#  'Save the Last Dance',
#  'Help, The',
#  'Tinker Tailor Soldier Spy',
#  'Tropic Thunder',
#  'Knocked Up',
#  'Mirrors',
#  'Perfect World, A',
#  'Full Metal Jacket',
#  '12 Monkeys',
#  'Officer and a Gentleman, An',
#  'Django Unchained',
#  'Out of Sight',
#  'Sleepless in Seattle',
#  'Cherry Falls',
#  'Dog Day Afternoon',
#  'Jurassic Park III',
#  'Losers, The',
#  'TRON: Legacy',
#  'Back to the Future II & III',
#  'Autumn in New York',
#  'Proposal, The',
#  'Custody',
#  'Bachelor Party, The',
#  'Easy A',
#  'Fighter, The',
#  'Heathers',
#  'Tourist, The',
#  'Gravity',
#  'Ghost Rider',
#  'Detroit Rock City',
#  'Mr Deeds Goes to Town',
#  'Meet Joe Black',
#  'Up in the Air',
#  'Arthur',
#  'Dark Knight Rises, The',
#  'Jerry Maguire',
#  'Village, The',
#  'Debt, The',
#  'Avatar',
#  'Neverending Story, The',
#  'Bonnie and Clyde',
#  'Wonder Boys',
#  'Nashville',
#  'Jackie Brown',
#  'Thunderbirds',
#  'Remember Me',
#  'Anastasia',
#  'From Dusk Till Dawn',
#  'Donnie Brasco',
#  'Evil Dead II: Dead by Dawn',
#  'Men Who Stare at Goats, The',
#  'Roommate, The',
#  'August: Osage County',
#  'Memento',
#  'Collateral',
#  'Leaving Las Vegas',
#  'Aladdin',
#  'Alien vs. Predator',
#  'Citizen Kane',
#  'How to Train Your Dragon',
#  'Star Wars: The Force Awakens',
#  'Kids',
#  'Anna Karenina',
#  'Dark Knight, The',
#  'Abyss, The',
#  'Lincoln',
#  'Six Degrees of Separation',
#  'Killing Zoe',
#  'Harry Potter and the Half-Blood Prince',
#  'Commando',
#  'Haunting, The',
#  'King of Comedy, The',
#  'Grosse Point Blank',
#  'Limitless',
#  'Fear and Loathing in Las Vegas',
#  'Monkeybone',
#  'Contact',
#  'Lord of the Rings: The Two Towers',
#  'Wild Things: Diamonds in the Rough',
#  'Sting, The',
#  'Return of the Apes',
#  'Kramer vs Kramer',
#  'Belle',
#  'Addams Family, The',
#  'Fantastic Mr Fox',
#  'Changeling',
#  'Hitchcock',
#  'Whiteout',
#  'Crow, The',
#  'When a Stranger Calls',
#  'Frozen River',
#  "Avventura, L' (The Adventure)",
#  'Life',
#  'Private Life of Sherlock Holmes, The',
#  'Mumford',
#  '1492: Conquest of Paradise',
#  'After School Special',
#  'Marley & Me',
#  'Believer, The',
#  'Adventures of Buckaroo Banzai Across the Eighth Dimension, The',
#  'Hotel Rwanda',
#  'Hellraiser: Hellseeker',
#  'Book of Eli, The',
#  'Dragonslayer',
#  'Harry Potter and the Goblet of Fire',
#  'Batman',
#  'Executive Decision',
#  'Ringu',
#  'Backdraft',
#  'Case 39',
#  'O Brother Where Art Thou?',
#  "Ocean's Eleven",
#  'Henry Fool',
#  '127 Hours',
#  'Indiana Jones and the Temple of Doom',
#  'Semi-Pro',
#  'Ed TV',
#  'Minority Report',
#  'Three Kings',
#  'Cider House Rules, The',
#  'Beavis and Butt-head Do America',
#  'Star Trek: Nemesis',
#  'Five Easy Pieces',
#  'Clueless',
#  'Fright Night (1985)',
#  'Armageddon',
#  'Megamind',
#  'Rushmore',
#  'Reindeer Games',
#  'Dark Star',
#  'Fracture',
#  'Ghost',
#  'Mystery Men',
#  'G.I. Jane',
#  'Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#  'Collateral Damage',
#  "April Fool's Day",
#  'Drive Angry',
#  'Jimmy and Judy',
#  'Paul',
#  'Hellboy 2: The Golden Army',
#  'Grifters, The',
#  'Birdman',
#  'Rise of the Guardians',
#  'Freaked',
#  'Airplane',
#  'Replacements, The',
#  'When Harry Met Sally',
#  'Music of the Heart',
#  'Get Shorty',
#  'Life of Pi',
#  'Three Men and a Baby',
#  'Law Abiding Citizen',
#  'Tremors',
#  'Hancock',
#  "I'll Do Anything",
#  'Shining, The',
#  'Thor',
#  'Twins',
#  'American Shaolin: King of Kickboxers II',
#  'Sugar and Spice',
#  'Indiana Jones and the Last Crusade',
#  'Mission Impossible II',
#  'American Outlaws',
#  'Kids Are All Right, The',
#  'Man in the Iron Mask',
#  'Spanglish',
#  'Legally Blonde',
#  'Napoleon Dynamite',
#  'Saw',
#  'Buffy the Vampire Slayer',
#  "All the President's Men",
#  'Fair Game',
#  'What About Bob?',
#  "Ferris Bueller's Day Off",
#  'While She Was Out',
#  'Hellbound: Hellraiser II',
#  'Shallow Grave',
#  'Batman Begins',
#  'Un Singe en Hiver',
#  'Rust and Bone',
#  'Creation',
#  'Lost Highway',
#  'Sling Blade',
#  'Raging Bull',
#  'Bourne Supremacy, The',
#  'Searchers, The',
#  'Confidence',
#  'Batman and Robin',
#  ...]

# %%
script.parts[8].split(sep="</b>")[1].split(sep="\n")
# Out:
# ['                           (filtered)',
#  '                    Internal pressure positive.  Assume',
#  '                    nominal hull integrity.  Hypersleep',
#  '                    capsules, style circa late twenties...',
#  '',
#  '        His gloved hand wipes at on opaque layer of dust on the',
#  '        canopy.',
#  '',
#  '        ANGLE INSIDE CAPSULE  as light stabs in where the dust is',
#  '        wiped away, illuminating a WOMAN, her face in peaceful',
#  '        repose.',
#  '',
#  '        WARRANT OFFICER RIPLEY, sole survivor of the Nostromo.',
#  "        Nestled next to her is JONES, the ship's wayward cat.",
#  '',
#  '']

# %%
header = script.parts[8].split(sep="</b>")[0]
content = script.parts[8].split(sep="</b>")[1].split(sep="\n")

# Determine number of lead spaces
spaces = re.compile('^[ ]+')        
line_info = []
for num, x in enumerate(content):
    count = spaces.match(x)
    if count == None:
        line_info.append((num,x.strip(),0,len(x)))
    else:
        line_info.append((num,x.strip(),count.end(),len(x)))
line_info
# Out:
# [(0, '(filtered)', 27, 37),
#  (1, 'Internal pressure positive.  Assume', 20, 55),
#  (2, 'nominal hull integrity.  Hypersleep', 20, 55),
#  (3, 'capsules, style circa late twenties...', 20, 58),
#  (4, '', 0, 0),
#  (5, 'His gloved hand wipes at on opaque layer of dust on the', 8, 63),
#  (6, 'canopy.', 8, 15),
#  (7, '', 0, 0),
#  (8, 'ANGLE INSIDE CAPSULE  as light stabs in where the dust is', 8, 65),
#  (9, 'wiped away, illuminating a WOMAN, her face in peaceful', 8, 62),
#  (10, 'repose.', 8, 15),
#  (11, '', 0, 0),
#  (12, 'WARRANT OFFICER RIPLEY, sole survivor of the Nostromo.', 8, 62),
#  (13, "Nestled next to her is JONES, the ship's wayward cat.", 8, 61),
#  (14, '', 0, 0),
#  (15, '', 0, 0)]

# %%
line_group = {}
spacing = 0
gap = 0
group = 1
lines = []
buffer = []
connect = " "
for x in line_info:
    if x[0] != 0:
        if x[2] == 0:
            spacing = 0
        elif x[2] == spacing:
            lines.append(x[0])
            buffer.append(x[1])
        else:
            line_group[group] = (lines, gap, connect.join(buffer))
            group += 1
            spacing = x[2]
            gap = x[2]
            lines = [x[0]]
            buffer = [x[1]]
    else:
        spacing = x[2]
        gap = x[2]
        lines = [x[0]]
        buffer = [x[1]]
line_group[group] = (lines, gap, connect.join(buffer))
line_group
# Out:
# {1: ([0], 27, '(filtered)'),
#  2: ([1, 2, 3],
#   20,
#   'Internal pressure positive.  Assume nominal hull integrity.  Hypersleep capsules, style circa late twenties...'),
#  3: ([5, 6],
#   8,
#   'His gloved hand wipes at on opaque layer of dust on the canopy.'),
#  4: ([8, 9, 10],
#   8,
#   'ANGLE INSIDE CAPSULE  as light stabs in where the dust is wiped away, illuminating a WOMAN, her face in peaceful repose.'),
#  5: ([12, 13],
#   8,
#   "WARRANT OFFICER RIPLEY, sole survivor of the Nostromo. Nestled next to her is JONES, the ship's wayward cat.")}

# %%
def parse_info(file):
    with open(SCRIPTS.format(file)) as f:
        data = j.load(f)

    d = bs.BeautifulSoup(data['info_raw'], "lxml")
    tds = d.find_all("td")

    raw = str(tds[2]).split(sep="<br/>")
    parse = raw[8:-2]

    parsed = {
        'opinion':raw[1],
        'rating':raw[4],
        'avg_usr_rtg':raw[6],
    }
    
    def checker(entry):
        if parsed[entry] == '\xa0\xa0None available':
            return parsed[entry] = None
        else:
            return parsed[entry] = parsed[entry].split(sep="> (")[1][:-11]
        

    for x in parse:
        if x[0:1] == '\n': 
            key = x.split(sep="</b>")[0].split(sep="<b>")[1]
            if x.split(sep="</b>")[1] != '':
                parsed[key] = x.split(sep="</b>")[1][3:]
            else:
                parsed[key] = []
                write = parsed[key]
        elif x == '':
            pass
        else:
            write.append(x.split(sep='">')[1][:-4])

    return parsed
# Out:
# {'Genres': ['Action', 'Horror', 'Sci-Fi', 'Thriller'],
#  'Script Date': 'May 1985',
#  'Writers': ['James Cameron'],
#  'avg_usr_rtg': '\xa0\xa0<img src="/images/rating/10-stars.gif"/> (9.80 out of 10)',
#  'opinion': '\xa0\xa0None available',
#  'rating': '\xa0\xa0Not available'}
